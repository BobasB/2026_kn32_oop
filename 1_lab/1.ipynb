# %% [markdown]
# # Пробуємо викоконати кодовий сніпет

# %% [markdown]
# > знизу буде код на Python

# %%
print("Вітання! ми почали програмувати на Python!")
# Out:
# Вітання! ми почали програмувати на Python!

# %%
print("Привіт, студенти!")
# Out:
# Привіт, студенти!

# %%
print("Привіт, від викладача!")
# Out:
# Привіт, від викладача!

# %%
def test_hello():
    print("Тестування функції виводу привітання")

test_hello()
# Out:
# Тестування функції виводу привітання
